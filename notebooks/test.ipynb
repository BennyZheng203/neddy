# %%
import requests
from astropy.io.votable import parse_single_table
from io import BytesIO
import pandas as pd
import matplotlib.pyplot as plt
# Define the target object
target_name = '3C 279'

# Construct the URL
url = f'https://vo.ned.ipac.caltech.edu/services/accessSED?REQUEST=getData&TARGETNAME={target_name}'

# Send the GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the VOTable data
    try:
        votable = parse_single_table(BytesIO(response.content))
    except IndexError:
        print(f'No Photometry/SED Data')
    data = votable.to_table()
else:
    print(f'Error: {response.status_code}')

# %%
df = data.to_pandas()

# %%
df.head()
# Out:
#    DataPointNumber  DataSpectralPassBand  DataFluxPublishedValue  \
# 0                1  50 GeV-2 TeV (Fermi)            2.110000e-12
# 1                2    0.01-1 TeV (Fermi)            1.860000e-11
# 2                3   100 MeV-100 GeV LAT            3.810000e-10
# 3                4   0.1-100 GeV (Fermi)            2.984000e-10
# 4                5   0.1-100 GeV (Fermi)            2.392000e-10
#
#    DataFluxPublishedStatErr DataFluxPublishedUnit  DataSpectralValue  \
# 0              1.060000e-12            erg/cm^2/s       2.480000e+26
# 1              2.200000e-12            erg/cm^2/s       1.220000e+26
# 2              8.600000e-12            erg/cm^2/s       1.210000e+25
# 3              4.800000e-12            erg/cm^2/s       1.210000e+25
# 4              3.100000e-12            erg/cm^2/s       1.210000e+25
#
#    DataFluxValue  DataFluxStatErr DataFluxUnit          DataRefcode  \
# 0   8.510000e-16     4.270000e-16           Jy  2016ApJS..222....5A
# 1   1.520000e-14     1.800000e-15           Jy  2017ApJS..232...18A
# 2   3.150000e-12     7.110000e-14           Jy  2010ApJS..188..405A
# 3   2.470000e-12     3.970000e-14           Jy  2012ApJS..199...31N
# 4   1.980000e-12     2.560000e-23           Jy  2015ApJS..218...23A
#
#   DataSignificance DataSpectralPublishedValue       DataFrequencyMode  \
# 0          1 sigma                  1.025 TeV  Broad-band measurement
# 1          1 sigma                   0.51 TeV  Broad-band measurement
# 2      uncertainty                  50050 MeV  Broad-band measurement
# 3          1 sigma                  50.05 GeV  Broad-band measurement
# 4          1 sigma                  50.05 GeV  Broad-band measurement
#
#                    DataTargetPos           DataSpatialMode  \
# 0      194.0600 -05.8046 (J2000)  Flux integrated from map
# 1  194.044281 -05.794593 (J2000)       From fitting to map
# 2        194.053 -05.791 (J2000)       From fitting to map
# 3        194.042 -05.794 (J2000)            Modelled datum
# 4        194.041 -05.791 (J2000)       From fitting to map
#
#                  DataQualifiers  \
# 0
# 1
# 2
# 3                      Variable
# 4  Variable; Gamma=2.34; Mod=LP
#
#                                         DataComments
# 0  From new raw data; NED frequency assigned to m...
# 1  From reprocessed raw data; NED frequency assig...
# 2  From new raw data; NED frequency assigned to m...
# 3  From new raw data; NED frequency assigned to m...
# 4  From new raw data; NED frequency assigned to m...

# %%
df[(df['DataSpectralValue'] > 4 * 10**12) & (df['DataSpectralValue'] < 8 * 10**12)]
# Out:
#      DataPointNumber DataSpectralPassBand  DataFluxPublishedValue  \
# 166              167    60 microns (IRAS)                   0.253
# 167              168    70 microns (MIPS)             1249585.000
# 168              169    70 microns (MIPS)              502300.000
#
#      DataFluxPublishedStatErr DataFluxPublishedUnit  DataSpectralValue  \
# 166                     0.043                    Jy       5.000000e+12
# 167                  1136.000                   uJy       4.200000e+12
# 168                   501.000                   uJy       4.200000e+12
#
#      DataFluxValue  DataFluxStatErr DataFluxUnit          DataRefcode  \
# 166          0.253         0.043000           Jy  1990IRASF.C...0000M
# 167          1.250         0.001140           Jy  2015ApJS..217...17H
# 168          0.502         0.000501           Jy  2015ApJS..217...17H
#
#     DataSignificance DataSpectralPublishedValue       DataFrequencyMode  \
# 166      uncertainty          60        microns  Broad-band measurement
# 167      uncertainty              71.42 microns  Broad-band measurement
# 168      uncertainty              71.42 microns  Broad-band measurement
#
#                      DataTargetPos         DataSpatialMode  \
# 166       125332.9 -053046 (B1950)  Flux in fixed aperture
# 167  194.046453 -05.789460 (J2000)     From fitting to map
# 168  194.046453 -05.789460 (J2000)  Flux in fixed aperture
#
#             DataQualifiers       DataComments
# 166  IRAS quality flag = 3  From new raw data
# 167  PSF flux; SN = 1400.0  From new raw data
# 168     aper. radius = 18"  From new raw data

# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd

# Step 1: Fetch the XML data from the URL
url = "http://nedwww.ipac.caltech.edu/cgi-bin/nph-datasearch?search_type=Photometry&objname=3C+279&of=xml_main"
response = requests.get(url)

# Step 2: Parse the XML content
root = ET.fromstring(response.content)

# Step 3: Extract data from the TABLEDATA section
data_rows = []
for tabledata in root.findall(".//TABLEDATA"):
    for tr in tabledata.findall("TR"):
        row = [td.text.strip() if td.text else None for td in tr.findall("TD")]
        data_rows.append(row)

# Step 4: Extract column headers from FIELD elements
columns = [field.get("name") for field in root.findall(".//FIELD")]

# Step 5: Create a DataFrame
df = pd.DataFrame(data_rows, columns=columns)

# Display the DataFrame
df.head()
# Out:
#   No.     Observed Passband Photometry Measurement  Uncertainty       Units  \
# 0   1  50 GeV-2 TeV (Fermi)               2.11E-12  +/-1.06E-12  erg/cm^2/s
# 1   2    0.01-1 TeV (Fermi)               1.86E-11  +/-2.20E-12  erg/cm^2/s
# 2   3   100 MeV-100 GeV LAT              381.0E-12   +/-8.6E-12  erg/cm^2/s
# 3   4   0.1-100 GeV (Fermi)              298.4E-12   +/-4.8E-12  erg/cm^2/s
# 4   5   0.1-100 GeV (Fermi)              239.2E-12   +/-3.1E-12  erg/cm^2/s
#
#   Frequency Flux Density Upper limit of uncertainty  \
# 0  2.48E+26     8.51E-16                   4.27E-16
# 1  1.22E+26     1.52E-14                   1.80E-15
# 2  1.21E+25     3.15E-12                   7.11E-14
# 3  1.21E+25     2.47E-12                   3.97E-14
# 4  1.21E+25     1.98E-12                   2.56E-23
#
#   Lower limit of uncertainty Upper limit of Flux Density  ... NED Uncertainty  \
# 0                   4.27E-16                        None  ...     +/-4.27E-16
# 1                   1.80E-15                        None  ...     +/-1.80E-15
# 2                   7.11E-14                        None  ...     +/-7.11E-14
# 3                   3.97E-14                        None  ...     +/-3.97E-14
# 4                   2.56E-23                        None  ...     +/-2.56E-23
#
#   NED Units              Refcode Significance Published frequency  \
# 0        Jy  2016ApJS..222....5A      1 sigma           1.025 TeV
# 1        Jy  2017ApJS..232...18A      1 sigma            0.51 TeV
# 2        Jy  2010ApJS..188..405A  uncertainty           50050 MeV
# 3        Jy  2012ApJS..199...31N      1 sigma           50.05 GeV
# 4        Jy  2015ApJS..218...23A      1 sigma           50.05 GeV
#
#            Frequency Mode           Coordinates Targeted  \
# 0  Broad-band measurement      194.0600 -05.8046 (J2000)
# 1  Broad-band measurement  194.044281 -05.794593 (J2000)
# 2  Broad-band measurement        194.053 -05.791 (J2000)
# 3  Broad-band measurement        194.042 -05.794 (J2000)
# 4  Broad-band measurement        194.041 -05.791 (J2000)
#
#                Spatial Mode                    Qualifiers  \
# 0  Flux integrated from map
# 1       From fitting to map
# 2       From fitting to map
# 3            Modelled datum                      Variable
# 4       From fitting to map  Variable; Gamma=2.34; Mod=LP
#
#                                             Comments
# 0  From new raw data; NED frequency assigned to m...
# 1  From reprocessed raw data; NED frequency assig...
# 2  From new raw data; NED frequency assigned to m...
# 3  From new raw data; NED frequency assigned to m...
# 4  From new raw data; NED frequency assigned to m...
#
# [5 rows x 21 columns]

# %% [markdown]
# Testing namesearch_phot

# %%
# Out:
#   1 / 1 (100.0%) URLs downloaded
# No results found
# []

# %%
import urllib
import requests
from fundamentals.download import multiobject_download
from astropy.io.votable import parse_single_table
from io import BytesIO
import logging as log
import pandas as pd

log.basicConfig(level=log.INFO)

def build_sed_query_urls(target_names):
    base_url = "https://vo.ned.ipac.caltech.edu/services/accessSED?REQUEST=getData&TARGETNAME="
    return [base_url + urllib.parse.quote(name) for name in target_names]

# List of target objects
target_names = ['3C 279']

# Build URLs for SED search
url_list = build_sed_query_urls(target_names)

# Download directory for SED data
download_directory = "/tmp"

# Download SED data using multiobject_download
sed_files = multiobject_download(
    urlList=url_list,
    downloadDirectory=download_directory,
    log=log,
    timeStamp=True,
    timeout=180,
    concurrentDownloads=1,
    resetFilename=False,
    credentials=False,
    longTime=True
)
# Out:
#   1 / 1 (100.0%) URLs downloaded

# %%
# Parse and display SED data
colour_map = {}

for name, file in zip(target_names, sed_files):
    for file in sed_files:
        with open(file, 'rb') as f:
            try:
                votable = parse_single_table(BytesIO(f.read()))
                data = votable.to_table()
                df = data.to_pandas()
                df
                #df = df[(df['DataSpectralValue'] > 430 * 10**12) & (df['DataSpectralValue'] < 800 * 10**12)]
                if df.nlargest(1, 'DataFluxValue')['DataFluxValue'].values[0] >= 530*10**12:
                    colour_map[name] = 'True'
                else:
                    colour_map[name]= 'False'
            except Exception as e:
                print(f"Failed to parse SED data from {file}: {e}")

# %%
for file in sed_files:
    with open(file, 'rb') as f:
        votable = parse_single_table(BytesIO(f.read()))
        data = votable.to_table()
        df = data.to_pandas()

# %%
df[(df['DataSpectralValue'] > 430 * 10**12) & (df['DataSpectralValue'] < 800 * 10**12)]
# Out:
#      DataPointNumber DataSpectralPassBand  DataFluxPublishedValue  \
# 103              104     log nu(Hz) 14.90                  -0.700
# 104              105             V (USNO)                  16.545
# 105              106     log nu(Hz) 14.85                  -0.660
# 106              107            B Johnson                  18.010
# 107              108          B (Johnson)                  15.321
# 108              109     log nu(Hz) 14.80                  -0.630
# 109              110     log nu(Hz) 14.75                  -0.590
# 110              111          V (Johnson)                  17.770
# 111              112            V Johnson                  17.750
# 112              113              V (AIT)                   3.980
# 113              114          V (Johnson)                  14.821
# 114              115     log nu(Hz) 14.70                  -0.560
# 115              116              R (AIT)                   5.180
# 116              117                    R                  15.870
# 117              118     log nu(Hz) 14.65                  -0.470
# 118              119          R (Johnson)                  14.328
#
#      DataFluxPublishedStatErr DataFluxPublishedUnit  DataSpectralValue  \
# 103                     0.020       log(f_nu) (mJy)       7.940000e+14
# 104                       NaN                   mag       7.400000e+14
# 105                     0.020       log(f_nu) (mJy)       7.080000e+14
# 106                       NaN                   mag       6.810000e+14
# 107                     0.046                   mag       6.810000e+14
# 108                     0.020       log(f_nu) (mJy)       6.310000e+14
# 109                     0.020       log(f_nu) (mJy)       5.620000e+14
# 110                     0.270                   mag       5.420000e+14
# 111                       NaN                   mag       5.420000e+14
# 112                       NaN                   mJy       5.420000e+14
# 113                     0.039                   mag       5.420000e+14
# 114                     0.020       log(f_nu) (mJy)       5.010000e+14
# 115                       NaN                   mJy       4.680000e+14
# 116                       NaN                   mag       4.680000e+14
# 117                     0.020       log(f_nu) (mJy)       4.470000e+14
# 118                     0.037                   mag       4.330000e+14
#
#      DataFluxValue  DataFluxStatErr DataFluxUnit          DataRefcode  \
# 103       0.000200         0.000009           Jy  1979ApJ...230...79N
# 104       0.000918              NaN           Jy  2015ApJ...810...14A
# 105       0.000219         0.000010           Jy  1979ApJ...230...79N
# 106       0.000266              NaN           Jy  1965ApJ...142.1307S
# 107       0.003170         0.000134           Jy  2009AJ....138..845O
# 108       0.000234         0.000011           Jy  1979ApJ...230...79N
# 109       0.000257         0.000012           Jy  1979ApJ...230...79N
# 110       0.000284         0.000080           Jy  1978ApJS...38..267O
# 111       0.000289              NaN           Jy  1965ApJ...142.1307S
# 112       0.003980              NaN           Jy  2004A&A...419...25F
# 113       0.004290         0.000154           Jy  2009AJ....138..845O
# 114       0.000275         0.000013           Jy  1979ApJ...230...79N
# 115       0.005180              NaN           Jy  2004A&A...419...25F
# 116       0.001380              NaN           Jy  2008ApJS..175...97H
# 117       0.000339         0.000016           Jy  1979ApJ...230...79N
# 118       0.005370         0.000183           Jy  2009AJ....138..845O
#
#             DataSignificance DataSpectralPublishedValue  \
# 103              uncertainty      14.90      log nu(Hz)
# 104  no uncertainty reported                     4050 A
# 105              uncertainty      14.85      log nu(Hz)
# 106  no uncertainty reported               4400       A
# 107          rms uncertainty                     4400 A
# 108              uncertainty      14.80      log nu(Hz)
# 109              uncertainty      14.75      log nu(Hz)
# 110              uncertainty                   5530   A
# 111  no uncertainty reported               5530       A
# 112  no uncertainty reported                   5530   A
# 113          rms uncertainty                     5530 A
# 114              uncertainty      14.70      log nu(Hz)
# 115  no uncertainty reported                   6400   A
# 116  no uncertainty reported                     6400 A
# 117              uncertainty      14.65      log nu(Hz)
# 118          rms uncertainty                     6930 A
#
#           DataFrequencyMode                    DataTargetPos  \
# 103  Broad-band measurement
# 104  Broad-band measurement      194.04653 -05.78931 (J2000)
# 105  Broad-band measurement
# 106  Broad-band measurement
# 107  Broad-band measurement
# 108  Broad-band measurement
# 109  Broad-band measurement
# 110  Broad-band measurement
# 111  Broad-band measurement
# 112  Broad-band measurement     12 56 11.1 -05 47 21 (J2000)
# 113  Broad-band measurement
# 114  Broad-band measurement
# 115  Broad-band measurement     12 56 11.1 -05 47 21 (J2000)
# 116  Broad-band measurement  12 56 11.17 -05 47 21.5 (J2000)
# 117  Broad-band measurement
# 118  Broad-band measurement
#
#               DataSpatialMode          DataQualifiers  \
# 103    Flux in fixed aperture
# 104     Integrated from scans
# 105    Flux in fixed aperture
# 106    Flux in fixed aperture
# 107    Flux in fixed aperture
# 108    Flux in fixed aperture
# 109    Flux in fixed aperture
# 110    Flux in fixed aperture            27" aperture
# 111    Flux in fixed aperture
# 112     Not reported in paper  Averaged over 10 years
# 113    Flux in fixed aperture
# 114    Flux in fixed aperture
# 115     Not reported in paper  Averaged over 10 years
# 116  Flux integrated from map
# 117    Flux in fixed aperture
# 118    Flux in fixed aperture
#
#                                           DataComments
# 103                                  From new raw data
# 104            Averaged from previously published data
# 105                                  From new raw data
# 106                                  From new raw data
# 107                                  From new raw data
# 108                                  From new raw data
# 109                                  From new raw data
# 110                                  From new raw data
# 111                                  From new raw data
# 112  From new raw data; Extinction-corrected for Mi...
# 113                                  From new raw data
# 114                                  From new raw data
# 115  From new raw data; Extinction-corrected for Mi...
# 116         Averaged new and previously published data
# 117                                  From new raw data
# 118                                  From new raw data

# %%
from neddy import conesearch
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

search = conesearch(
    log=logging,
    ra=197.448762,
    dec=-23.383962,
    radiusArcsec=60,
    nearestOnly=False,
    unclassified=False,
    outputFilePath=False,
    verbose=True,
    redshift=False
)

# %%
results = search.get()
# Out:
# http://ned.ipac.caltech.edu/cgi-bin/objsearch?in_csys=Equatorial&in_equinox=J2000.0&lon=197.448762d&lat=-23.383962d&radius=1.0&hconst=73&omegam=0.27&omegav=0.73&corr_z=1&z_constraint=Unconstrained&z_value1=&z_value2=&z_unit=z&ot_include=IrS&nmp_op=ANY&out_csys=Equatorial&out_equinox=J2000.0&obj_sort=Distance+to+search+center&of=ascii_bar&zv_breaker=30000.0&list_limit=500&img_stamp=NO&search_type=Near+Position+Search&ot_include=G&in_objtypes1=Galaxies&in_objtypes1=GPairs&in_objtypes1=GTriples&in_objtypes1=GGroups&in_objtypes1=GClusters&in_objtypes1=QSO&in_objtypes1=QSOGroups&in_objtypes1=GravLens&in_objtypes1=AbsLineSys&in_objtypes1=EmissnLine&in_objtypes1=GClstr&in_objtypes1=GGroup&in_objtypes1=GPair&in_objtypes1=GTrpl
# 1 NED conesearch URLs have been built. Requesting from NED ...
#   1 / 1 (100.0%) URLs downloaded
# 1 conesearch results downloaded from NED
#   2 returned from single NED conesearch
#   1 / 1 (100.0%) URLs downloaded
# No results found

# %% [markdown]
# Testing namesearch with sed data

# %%
from neddy import namesearch
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

search = namesearch(names=['3C 279', 'NGC 1275', 'M31', 'NGC 4993'], log=logging, verbose=True, SED=True)

results = search.get()
# Out:
# Unexpected error: 'module' object is not callable

# %%
print(type(search))
# Out:
# <class 'neddy.namesearch.namesearch'>

# %%
import neddy

# %%
neddy
# Out:
# <module 'neddy' from '/Users/jhzhe/Cloned_Repos/neddy/neddy/__init__.py'>

# %%
import pandas as pd
import requests
from io import StringIO

# URL for the NED Photometry data
url = "https://ned.ipac.caltech.edu/cgi-bin/datasearch?objname=M51&meas_type=bot&ebars_spec=ebars&label_spec=no&x_spec=freq&y_spec=Fnu_jy&xr=-1&of=ascii_bar&search_type=Photometry"

# Step 1: Download the data
response = requests.get(url)

data = response.content.decode('utf-8')

# %%
from __future__ import print_function
from neddy import _basesearch
import urllib
import os
import sys
from astropy.io.votable import parse_single_table
from io import BytesIO
import pandas as pd
from future import standard_library
standard_library.install_aliases()
import requests
from io import StringIO
import time
from tqdm import tqdm

def download_sed_query_1(names):
    queryList = build_sed_query_url(names)

    colour_map = {}
    # Download photometry data for each object, determine colour map and save to file. 
    if not os.path.exists("/Users/jhzhe/dev/MPhys-Project/output_data/temp/dict.txt"):
        f = open("/Users/jhzhe/dev/MPhys-Project/output_data/temp/dict.txt","w+")
        f.close()

    f = open("/Users/jhzhe/dev/MPhys-Project/output_data/temp/dict.txt","r+")
    for name, query in tqdm(zip(names, queryList), total=len(names), desc="Downloading SED data"):
            if name in f.read():
                f.close()
                continue
            
            response = requests.get(query)
            data = response.content.decode('utf-8')

            df = pd.read_csv(
                StringIO(data),
                sep='|',
                skiprows=16,
                engine='python'
            )


            df = df[(df['Frequency'] >= 430 * 10**12) & (df['Frequency'] <= 800 * 10**12)]
            if df.nlargest(1, 'Flux Density')['Flux Density'].values[0] <= 800*10**12 and df.nlargest(1, 'Flux Density')['Flux Density'].values[0] >= 600*10**12:
                colour_map[name] = '1'
            elif df.nlargest(1, 'Flux Density')['Flux Density'].values[0] >= 530*10**12 and df.nlargest(1, 'Flux Density')['Flux Density'].values[0] <= 600*10**12:
                colour_map[name] = '2'
            else:
                colour_map[name]= '3'
            
            f.seek(0)
            f.truncate()
            f.write(str(dict))
            time.sleep(1) # sleep for 1 second to avoid ban
                
    return colour_map

def build_sed_query_url(names):
    base_url = 'https://ned.ipac.caltech.edu/cgi-bin/datasearch?'
    params = {
        'search_type': 'Photometry',
        'meas_type': 'bot',
        'ebars_spec': 'ebars',
        'label_spec': 'no',
        'x_spec': 'freq',
        'y_spec': 'Fnu_jy',
        'xr': '-1',
        'of': 'ascii_bar'
    }

    return [base_url + urllib.parse.urlencode({**params, 'objname': name}) for name in names]

# %%
url = build_sed_query_url(['3C 279', 'NGC 1275', 'M31'])

# %%
colour_map = download_sed_query_1(['3C 279', 'NGC 1275', 'M31'])
# Out:
# Downloading SED data: 100%|██████████| 3/3 [00:13<00:00,  4.65s/it]

# %%
colour_map
# Out:
# {'3C 279': '3', 'NGC 1275': '3', 'M31': '3'}

# %%
from neddy.photometrysearch import PhotometrySearch

# %%
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

ra_list = [194.046527, 49.950667]
dec_list = [-5.789313, 41.511695]
search = PhotometrySearch(
    names=['3C 279', 'NGC 1275'],
    log=logging,
    verbose=True,
    SED=True,
    ra_list=ra_list,
    dec_list=dec_list,
    filters = ['Landolt U', 'Landolt B', 'Landolt V', 'Landolt R', 'Landolt I']
)

# %%
colour_map = search.get()
# Out:
# 2025-01-21 17:31:44,780 - INFO - Starting SED queries for names.
# Downloading SED data:   0%|          | 0/2 [00:00<?, ?it/s]/Users/jhzhe/Cloned_Repos/neddy/neddy/photometrysearch.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[(df['Frequency'] >= low_freq) & (df['Frequency'] <= high_freq), 'Band'] = band
# /Users/jhzhe/Cloned_Repos/neddy/neddy/photometrysearch.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['Band'] == key, 'Flux Density Adjusted'] = df['Flux Density'] * 10**(-value / 2.5)
# /Users/jhzhe/Cloned_Repos/neddy/neddy/photometrysearch.py:201: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Flux Density Adjusted'] = df['Flux Density Adjusted'].fillna(df['Flux Density'])
# Downloading SED data:  50%|█████     | 1/2 [00:04<00:04,  4.94s/it]/Users/jhzhe/Cloned_Repos/neddy/neddy/photometrysearch.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[(df['Frequency'] >= low_freq) & (df['Frequency'] <= high_freq), 'Band'] = band
# /Users/jhzhe/Cloned_Repos/neddy/neddy/photometrysearch.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['Band'] == key, 'Flux Density Adjusted'] = df['Flux Density'] * 10**(-value / 2.5)
# /Users/jhzhe/Cloned_Repos/neddy/neddy/photometrysearch.py:201: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Flux Density Adjusted'] = df['Flux Density Adjusted'].fillna(df['Flux Density'])
# Downloading SED data: 100%|██████████| 2/2 [00:10<00:00,  5.42s/it]

# %%
colour_map
# Out:
# {'3C 279': '3', 'NGC 1275': '3'}
